# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')
# Out:
# c:\users\mitesh manoj adake\appdata\local\programs\python\python38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\mitesh manoj adake\appdata\local\programs\python\python38\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# c:\users\mitesh manoj adake\appdata\local\programs\python\python38\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data = pd.read_csv("D:/Sem - 7 Lab/LP-3/ML/1/uber.csv")
data.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df = data.copy()
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df = df.drop(['Unnamed: 0','key'],axis=1)
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %% [markdown]
# ## Haversine Formula
# Calculatin the distance between the pickup and drop co-ordinates using the Haversine formual for accuracy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def haversine (lon_1, lon_2, lat_1, lat_2):
    
    lon_1, lon_2, lat_1, lat_2 = map(np.radians, [lon_1, lon_2, lat_1, lat_2])  #Degrees to Radians
    
    
    diff_lon = lon_2 - lon_1
    diff_lat = lat_2 - lat_1
    

    km = 2 * 6371 * np.arcsin(np.sqrt(np.sin(diff_lat/2.0)**2 + 
                                      np.cos(lat_1) * np.cos(lat_2) * np.sin(diff_lon/2.0)**2))
    
    return km

# %%
df['Distance']= haversine(df['pickup_longitude'], df['dropoff_longitude'],
                             df['pickup_latitude'], df['dropoff_latitude'])

df['Distance'] = df['Distance'].astype(float).round(2)

# %%
df.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  Distance
# 0         -73.999512         40.723217                1      1.68
# 1         -73.994710         40.750325                1      2.46
# 2         -73.962565         40.772647                1      5.04
# 3         -73.965316         40.803349                3      1.66
# 4         -73.973082         40.761247                5      4.48

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %% [markdown]
# ## Outliers
# We can get rid of the trips with very large distances that are outliers as well as trips with 0 distance.

# %%
df.drop(df[df['Distance'] > 60].index, inplace = True)
df.drop(df[df['Distance'] == 0].index, inplace = True)
df.drop(df[df['Distance'] < 0].index, inplace = True)

df.drop(df[df['fare_amount'] == 0].index, inplace = True)
df.drop(df[df['fare_amount'] < 0].index, inplace = True)

# %%
df.drop(df[df['Distance'] > 100].index, inplace = True)
df.drop(df[df['fare_amount'] > 100].index, inplace = True)

# %% [markdown]
# Also removing rows with non-plausible fare amounts and distance travelled

# %%
df.drop(df[(df['fare_amount']>100) & (df['Distance']<1)].index, inplace = True )
df.drop(df[(df['fare_amount']<100) & (df['Distance']>100)].index, inplace = True )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193436 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        193436 non-null  float64
#  1   pickup_datetime    193436 non-null  object
#  2   pickup_longitude   193436 non-null  float64
#  3   pickup_latitude    193436 non-null  float64
#  4   dropoff_longitude  193436 non-null  float64
#  5   dropoff_latitude   193436 non-null  float64
#  6   passenger_count    193436 non-null  int64
#  7   Distance           193436 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 17.3+ MB

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %% [markdown]
# Separating the date and time into separate columns for more usability

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

df['Year'] = df['pickup_datetime'].apply(lambda time: time.year)
df['Month'] = df['pickup_datetime'].apply(lambda time: time.month)
df['Day'] = df['pickup_datetime'].apply(lambda time: time.day)
df['Day of Week'] = df['pickup_datetime'].apply(lambda time: time.dayofweek)
df['Day of Week_num'] = df['pickup_datetime'].apply(lambda time: time.dayofweek)
df['Hour'] = df['pickup_datetime'].apply(lambda time: time.hour)

day_map = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['Day of Week'] = df['Day of Week'].map(day_map)

df['counter'] = 1

# %% [markdown]
# Creating separate coumns for pickup and droppoff coordinates for more usability.

# %%
df['pickup'] = df['pickup_latitude'].astype(str) + "," + df['pickup_longitude'].astype(str)   
df['drop off'] = df['dropoff_latitude'].astype(str) + "," + df['dropoff_longitude'].astype(str)

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  Distance  Year  \
# 0         -73.999512         40.723217                1      1.68  2015
# 1         -73.994710         40.750325                1      2.46  2009
# 2         -73.962565         40.772647                1      5.04  2009
# 3         -73.965316         40.803349                3      1.66  2009
# 4         -73.973082         40.761247                5      4.48  2014
#
#    Month  Day Day of Week  Day of Week_num  Hour  counter  \
# 0      5    7         Thu                3    19        1
# 1      7   17         Fri                4    20        1
# 2      8   24         Mon                0    21        1
# 3      6   26         Fri                4     8        1
# 4      8   28         Thu                3    17        1
#
#                                  pickup                           drop off
# 0  40.73835372924805,-73.99981689453125  40.72321701049805,-73.99951171875
# 1                  40.728225,-73.994355                40.750325,-73.99471
# 2                   40.74077,-74.005043               40.772647,-73.962565
# 3                  40.790844,-73.976124               40.803349,-73.965316
# 4                  40.744085,-73.925023       40.761247,-73.97308199999999

# %% [markdown]
# ## Correlation

# %%
corr = df.corr()

corr.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_d499d_row0_col0, #T_d499d_row1_col1, #T_d499d_row1_col3, #T_d499d_row2_col2, #T_d499d_row3_col1, #T_d499d_row3_col3, #T_d499d_row4_col4, #T_d499d_row5_col5, #T_d499d_row6_col6, #T_d499d_row7_col7, #T_d499d_row8_col8, #T_d499d_row9_col9, #T_d499d_row10_col10, #T_d499d_row11_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d499d_row0_col1, #T_d499d_row0_col3, #T_d499d_row7_col1, #T_d499d_row7_col3 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_d499d_row0_col2, #T_d499d_row5_col2, #T_d499d_row10_col2 {
#   background-color: #6dc5a9;
#   color: #000000;
# }
# #T_d499d_row0_col4, #T_d499d_row5_col4, #T_d499d_row8_col1, #T_d499d_row8_col3, #T_d499d_row10_col4 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_d499d_row0_col5, #T_d499d_row0_col9, #T_d499d_row2_col1, #T_d499d_row2_col3, #T_d499d_row5_col9, #T_d499d_row6_col9, #T_d499d_row9_col0, #T_d499d_row10_col0, #T_d499d_row10_col9, #T_d499d_row11_col5, #T_d499d_row11_col9 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_d499d_row0_col6 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_d499d_row0_col7 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_d499d_row0_col8, #T_d499d_row6_col7 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_d499d_row0_col10, #T_d499d_row1_col10, #T_d499d_row3_col10, #T_d499d_row7_col10, #T_d499d_row9_col8, #T_d499d_row9_col10, #T_d499d_row9_col11 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_d499d_row0_col11, #T_d499d_row7_col6 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_d499d_row0_col12, #T_d499d_row1_col12, #T_d499d_row2_col12, #T_d499d_row3_col12, #T_d499d_row4_col12, #T_d499d_row5_col12, #T_d499d_row6_col12, #T_d499d_row7_col12, #T_d499d_row8_col12, #T_d499d_row9_col12, #T_d499d_row10_col12, #T_d499d_row11_col12, #T_d499d_row12_col0, #T_d499d_row12_col1, #T_d499d_row12_col2, #T_d499d_row12_col3, #T_d499d_row12_col4, #T_d499d_row12_col5, #T_d499d_row12_col6, #T_d499d_row12_col7, #T_d499d_row12_col8, #T_d499d_row12_col9, #T_d499d_row12_col10, #T_d499d_row12_col11, #T_d499d_row12_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d499d_row1_col0, #T_d499d_row1_col6, #T_d499d_row1_col9, #T_d499d_row2_col6, #T_d499d_row3_col6, #T_d499d_row3_col9, #T_d499d_row5_col0, #T_d499d_row9_col6 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_d499d_row1_col2, #T_d499d_row1_col4, #T_d499d_row2_col5, #T_d499d_row2_col9, #T_d499d_row3_col2, #T_d499d_row3_col4, #T_d499d_row4_col1, #T_d499d_row4_col3, #T_d499d_row4_col5, #T_d499d_row4_col9, #T_d499d_row7_col8, #T_d499d_row8_col7, #T_d499d_row8_col9, #T_d499d_row10_col11, #T_d499d_row11_col0, #T_d499d_row11_col6, #T_d499d_row11_col10 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_d499d_row1_col5, #T_d499d_row3_col5, #T_d499d_row6_col5, #T_d499d_row8_col5 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_d499d_row1_col7, #T_d499d_row2_col8, #T_d499d_row3_col7, #T_d499d_row4_col8, #T_d499d_row5_col8, #T_d499d_row5_col10, #T_d499d_row6_col8 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_d499d_row1_col8, #T_d499d_row3_col8, #T_d499d_row6_col10, #T_d499d_row10_col8, #T_d499d_row11_col8 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_d499d_row1_col11, #T_d499d_row3_col11, #T_d499d_row4_col11, #T_d499d_row7_col11 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_d499d_row2_col0, #T_d499d_row4_col0, #T_d499d_row7_col9 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_d499d_row2_col4, #T_d499d_row4_col2 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_d499d_row2_col7, #T_d499d_row4_col7, #T_d499d_row5_col11, #T_d499d_row9_col7 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_d499d_row2_col10, #T_d499d_row4_col10, #T_d499d_row8_col10 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_d499d_row2_col11, #T_d499d_row8_col11 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_d499d_row3_col0, #T_d499d_row4_col6 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_d499d_row5_col1, #T_d499d_row5_col3, #T_d499d_row6_col1, #T_d499d_row6_col3, #T_d499d_row8_col4, #T_d499d_row10_col1, #T_d499d_row10_col3 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_d499d_row5_col6, #T_d499d_row8_col0, #T_d499d_row8_col6, #T_d499d_row10_col5 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_d499d_row5_col7, #T_d499d_row10_col7, #T_d499d_row11_col7 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_d499d_row6_col0 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_d499d_row6_col2, #T_d499d_row7_col4, #T_d499d_row8_col2, #T_d499d_row9_col4 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_d499d_row6_col4, #T_d499d_row11_col1, #T_d499d_row11_col3, #T_d499d_row11_col4 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_d499d_row6_col11, #T_d499d_row10_col6 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_d499d_row7_col0 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_d499d_row7_col2, #T_d499d_row9_col2 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_d499d_row7_col5, #T_d499d_row9_col5 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_d499d_row9_col1, #T_d499d_row9_col3 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_d499d_row11_col2 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# </style>
# <table id="T_d499d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fare_amount</th>
#       <th class="col_heading level0 col1" >pickup_longitude</th>
#       <th class="col_heading level0 col2" >pickup_latitude</th>
#       <th class="col_heading level0 col3" >dropoff_longitude</th>
#       <th class="col_heading level0 col4" >dropoff_latitude</th>
#       <th class="col_heading level0 col5" >passenger_count</th>
#       <th class="col_heading level0 col6" >Distance</th>
#       <th class="col_heading level0 col7" >Year</th>
#       <th class="col_heading level0 col8" >Month</th>
#       <th class="col_heading level0 col9" >Day</th>
#       <th class="col_heading level0 col10" >Day of Week_num</th>
#       <th class="col_heading level0 col11" >Hour</th>
#       <th class="col_heading level0 col12" >counter</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d499d_level0_row0" class="row_heading level0 row0" >fare_amount</th>
#       <td id="T_d499d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d499d_row0_col1" class="data row0 col1" >0.012292</td>
#       <td id="T_d499d_row0_col2" class="data row0 col2" >-0.008891</td>
#       <td id="T_d499d_row0_col3" class="data row0 col3" >0.010831</td>
#       <td id="T_d499d_row0_col4" class="data row0 col4" >-0.009044</td>
#       <td id="T_d499d_row0_col5" class="data row0 col5" >0.014409</td>
#       <td id="T_d499d_row0_col6" class="data row0 col6" >0.895513</td>
#       <td id="T_d499d_row0_col7" class="data row0 col7" >0.124050</td>
#       <td id="T_d499d_row0_col8" class="data row0 col8" >0.024850</td>
#       <td id="T_d499d_row0_col9" class="data row0 col9" >0.000277</td>
#       <td id="T_d499d_row0_col10" class="data row0 col10" >0.004881</td>
#       <td id="T_d499d_row0_col11" class="data row0 col11" >-0.020270</td>
#       <td id="T_d499d_row0_col12" class="data row0 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d499d_level0_row1" class="row_heading level0 row1" >pickup_longitude</th>
#       <td id="T_d499d_row1_col0" class="data row1 col0" >0.012292</td>
#       <td id="T_d499d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d499d_row1_col2" class="data row1 col2" >-0.949099</td>
#       <td id="T_d499d_row1_col3" class="data row1 col3" >0.999885</td>
#       <td id="T_d499d_row1_col4" class="data row1 col4" >-0.993976</td>
#       <td id="T_d499d_row1_col5" class="data row1 col5" >0.009176</td>
#       <td id="T_d499d_row1_col6" class="data row1 col6" >0.005356</td>
#       <td id="T_d499d_row1_col7" class="data row1 col7" >0.013480</td>
#       <td id="T_d499d_row1_col8" class="data row1 col8" >-0.007497</td>
#       <td id="T_d499d_row1_col9" class="data row1 col9" >0.019531</td>
#       <td id="T_d499d_ro

# %% [markdown]
# There is some correlation between the distance and fare amount.<br>
# Implementing simple linear regression model using these two varaibles.

# %%
X = df['Distance'].values.reshape(-1, 1)       
y = df['fare_amount'].values.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
y_std = std.fit_transform(y)
print(y_std)

x_std = std.fit_transform(X)
print(x_std)
# Out:
# [[-0.40638221]
#  [-0.38489719]
#  [ 0.17371326]
#  ...
#  [ 2.10736482]
#  [ 0.3455934 ]
#  [ 0.30262337]]
# [[-0.46769936]
#  [-0.24942881]
#  [ 0.472543  ]
#  ...
#  [ 2.65804681]
#  [ 0.05279195]
#  [ 0.57887993]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_std, y_std, test_size=0.3, random_state=0)

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

l_reg = LinearRegression()
l_reg.fit(X_train, y_train)

print("Training set score: {:.2f}".format(l_reg.score(X_train, y_train)))
print("Test set score: {:.7f}".format(l_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.80
# Test set score: 0.8050688

# %%
y_pred = l_reg.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))

print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))

print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.2438330049716194
# Mean Squared Error: 0.1926995801043055
# Root Mean Squared Error: 0.4389756030855308

# %%
print(l_reg.intercept_)
print(l_reg.coef_)
# Out:
# [0.00029241]
# [[0.89503692]]

# %% [markdown]
# Plotting the linear regression line against the training and test set side by side.

# %%
plt.subplot(2, 2, 1)
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.title("Fare vs Distance (Training Set)")
plt.ylabel("fare_amount")
plt.xlabel("Distance")

plt.subplot(2, 2, 2)
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.ylabel("fare_amount")
plt.xlabel("Distance")
plt.title("Fare vs Distance (Test Set)")


plt.tight_layout()
plt.rcParams["figure.figsize"] = (32,22)
plt.show()

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

r_reg = RandomForestRegressor(n_estimators = 50, random_state = 0)

r_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
predictions = r_reg.predict(X_test)

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))

print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions))

print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 0.24670010997672112
# Mean Squared Error: 0.19753474247914912
# Root Mean Squared Error: 0.4444488074898493
